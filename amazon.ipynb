# %%
from bs4 import BeautifulSoup
from flask import Flask
import requests
import hashlib
import time
import datetime
from tkinter import ttk
import smtplib

# %%
URL='https://www.amazon.in/dp/B097R25DP7/ref=syn_sd_onsite_desktop_84?psc=1&pd_rd_plhdr=t&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEySjdTMVE1UzRGOTJLJmVuY3J5cHRlZElkPUEwOTEzMzg1MU5HMzZKTTIySTk1SSZlbmNyeXB0ZWRBZElkPUEwNDU5NzgxMkdZNlFSWTE1RElBNiZ3aWRnZXROYW1lPXNkX29uc2l0ZV9kZXNrdG9wJmFjdGlvbj1jbGlja1JlZGlyZWN0JmRvTm90TG9nQ2xpY2s9dHJ1ZQ=='
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
page=requests.get(URL,headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2=BeautifulSoup(soup1.prettify(),"html.parser")
title=soup2.find(id='productTitle').get_text()
image_url=soup2.find(id='https://www.amazon.in/Noise-ColorFit-Smartwatch-Monitoring-Waterproof/dp/B097R25DP7/?_encoding=UTF8&pd_rd_w=rexVE&content-id=amzn1.sym.ee853eb9-cee5-4961-910b-2f169311a086&pf_rd_p=ee853eb9-cee5-4961-910b-2f169311a086&pf_rd_r=GF2C0R4FQRG8W7JGJRKD&pd_rd_wg=X3xJK&pd_rd_r=e37133cf-8b6b-4247-9b1f-0d147cf5b2fd&ref_=pd_gw_ci_mcx_mr_hp_atf_m')
price = soup2.find(id='corePrice_desktop').get_text()
details=soup2.find(id='featurebullets_feature_div').get_text()
print(title)
print(price)
print(image_url)
print(details)
# Out:
#             Noise ColorFit Pulse Spo2 Smart Watch with 10 days battery life, 60+ Watch Faces, 1.4" Full Touch HD Display Smartwatch, 24*7 Heart Rate Monitor Smart Band, Sleep Monitoring Smart Watches for Men and Women & IP68 Waterproof (Jet Black)
#
#
#
#
#
#
#               M.R.P.:
#
#
#
#
#                 ₹4,999.00
#
#
#                 ₹4,999.00
#
#
#
#
#
#
#
#
#
#
#
#
#               Deal Price:
#
#
#
#
#                 ₹1,699.00
#
#
#                 ₹1,699.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               You Save:
#
#
#
#
#
#                  ₹3,300.00
#
#
#                  ₹3,300.00
#
#
#                (66%)
#
#
#
#
#
#
#
#
#
#
#
#
#                Inclusive of all taxes
#
#
#
#
#
#
# None
#
#
#
#
#            About this item
#
#
#
#
#              [10-day battery]: With a battery backup of 10 days, just concentrate on your game without stopping.
#
#
#
#
# ...

# %%
URL='https://www.amazon.in/Strontium-Pollex-USB-Stick-Flash/dp/B06WD3WT86/?_encoding=UTF8&pd_rd_w=6Mti4&content-id=amzn1.sym.2c2b5663-2c1f-48e2-a729-9de758730abc&pf_rd_p=2c2b5663-2c1f-48e2-a729-9de758730abc&pf_rd_r=GF2C0R4FQRG8W7JGJRKD&pd_rd_wg=X3xJK&pd_rd_r=e37133cf-8b6b-4247-9b1f-0d147cf5b2fd&ref_=pd_gw_ci_mcx_mi'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
page=requests.get(URL,headers=headers)
soup1 = BeautifulSoup(page.content, "html.parser")
soup2=BeautifulSoup(soup1.prettify(),"html.parser")
title=soup2.find(id='productTitle').get_text()
image_url=soup2.find(id='https://www.amazon.in/Noise-ColorFit-Smartwatch-Monitoring-Waterproof/dp/B097R25DP7/?_encoding=UTF8&pd_rd_w=rexVE&content-id=amzn1.sym.ee853eb9-cee5-4961-910b-2f169311a086&pf_rd_p=ee853eb9-cee5-4961-910b-2f169311a086&pf_rd_r=GF2C0R4FQRG8W7JGJRKD&pd_rd_wg=X3xJK&pd_rd_r=e37133cf-8b6b-4247-9b1f-0d147cf5b2fd&ref_=pd_gw_ci_mcx_mr_hp_atf_m')
price = soup2.find(id='corePrice_desktop').get_text()
details=soup2.find(id='featurebullets_feature_div').get_text()
print(title)
print(price)
print(image_url)
print(details)
# Out:
#             Strontium Pollex USB 64 GB Flash Drive (Black, Red)
#
#
#
#
#
#
#               M.R.P.:
#
#
#
#
#                 ₹1,499.00
#
#
#                 ₹1,499.00
#
#
#
#
#
#
#
#
#
#
#
#
#               Deal Price:
#
#
#
#
#                 ₹687.00
#
#
#                 ₹687.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               You Save:
#
#
#
#
#
#                  ₹812.00
#
#
#                  ₹812.00
#
#
#                (54%)
#
#
#
#
#
#
#
#
#
#
#
#
#                Inclusive of all taxes
#
#
#
#
#
#
# None
#
#
#
#
#            About this item
#
#
#
#
#              High speed data transfer performance
#
#
#
#
#              Read rate of 25mbps and write rate of 5mbps
#
#
#
#
#              Interface - Standard Type A USB (USB 2.0)
#
#
#
#
#              Support plug and play
#
#
#
#
#              Variable clock rate of 0 to 480MHz
#
#
#
#
#              Low power consumption
#
#
#
#
#              USB powered with no external power required
#
#
#
#
#
# ...

# %%
price=price.strip()[1:]
title=title.strip()
print(title)
print(image_url)
print(price)
print(details)
# Out:
# Strontium Pollex USB 64 GB Flash Drive (Black, Red)
# None
# .R.P.:
#
#
#
#
#                 ₹1,499.00
#
#
#                 ₹1,499.00
#
#
#
#
#
#
#
#
#
#
#
#
#               Deal Price:
#
#
#
#
#                 ₹687.00
#
#
#                 ₹687.00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               You Save:
#
#
#
#
#
#                  ₹812.00
#
#
#                  ₹812.00
#
#
#                (54%)
#
#
#
#
#
#
#
#
#
#
#
#
#                Inclusive of all taxes
#
#
#
#
#            About this item
#
#
#
#
#              High speed data transfer performance
#
#
#
#
#              Read rate of 25mbps and write rate of 5mbps
#
#
#
#
#              Interface - Standard Type A USB (USB 2.0)
#
#
#
#
#              Support plug and play
#
#
#
#
#              Variable clock rate of 0 to 480MHz
#
#
#
#
#              Low power consumption
#
#
#
#
#              USB powered with no external power required
#
#
#
#
#
#            ›
#
#
#            See more product details

# %%
import csv
header = ['Title','image_url','price','details']
data=[title,image_url,price,details]
with open('Amazon.csv','w',newline='',encoding='UTF8')as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)
